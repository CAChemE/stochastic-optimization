# %%
import numpy as np
from plotPSO import plotPSO_2D, plotPSO_1D
from optitestfuns import ackley

# %%
# Testing 2D plot

limits=([-5,5],[-5,5])

x_lo = limits[0][0]
x_up = limits[0][1]
y_lo = limits[1][0]
y_up = limits[1][1]

n_particles = 10

x_particles = np.random.uniform(x_lo, x_up, size=n_particles)
y_particles = np.random.uniform(y_lo, y_up, size=n_particles)

particle_xycoordinates = (x_particles, y_particles)

fig, ax = plotPSO_2D(ackley, particle_xycoordinates, limits)

# %%
# Testing 1D plot

limits=(-5,5)

x_lo = limits[0]
x_up = limits[1]

n_particles = 10

x_particles = np.random.uniform(x_lo, x_up, size=n_particles)
y_particles = np.random.uniform(y_lo, y_up, size=n_particles)

particle_xycoordinates = x_particles

fig, ax = plotPSO_1D(ackley, particle_xycoordinates, limits )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2d51c4025ec8> in <module>()
#      13 particle_xycoordinates = x_particles
#      14
# ---> 15 fig, ax = plotPSO_1D(ackley, particle_xycoordinates, limits )
#
# C:\Users\SERVER\Documents\GitHub\stochastic-optimization\PSO\2D\plotPSO.py in plotPSO_1D(function, particle_xcoordinates, limits, n_points, *arg)
#     109
#     110     plt.show()
# --> 111     ax.plot(x,y)
#     112
#     113     return fig, ax
#
# NameError: name 'y' is not defined
